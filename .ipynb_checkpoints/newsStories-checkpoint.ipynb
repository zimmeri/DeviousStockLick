# %%
import os
import datetime
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as soup
from urllib.request import Request, urlopen

# %%
def getTargets():
    targets = pd.read_csv('targetSp.csv')
    return targets.Symbol.to_numpy()

# %%
def getNews(html):
    try:
        news = pd.read_html(str(html), attrs = {'class': 'fullview-news-outer'})[0]
        links = []
        for a in html.find_all('a', class_="tab-link-news"):
            links.append(a['href'])
        
        # Clean up news dataframe
        news.columns = ['Date', 'Headline']
        news['Link'] = links
        return news

    except Exception as e:
        return e

# %%
def requestTargets(target):
    url = ("http://finviz.com/quote.ashx?t=" + target.lower())
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()
    html = soup(webpage, "html.parser")
    return getNews(html).head(5)

# %%
def runDaily():
    targets = getTargets()
    links = pd.DataFrame()
    for target in targets:
        newsList = requestTargets(target)
        newsList['target'] = target
        links = links.append(newsList)
    links = links.reset_index(drop=True)
    if not os.path.exists('data/' +(datetime.date.today() + datetime.timedelta(days=1)).strftime('%Y-%m-%d')):
        os.mkdir('data/' +(datetime.date.today() + datetime.timedelta(days=1)).strftime('%Y-%m-%d'))
    links.to_csv('data/' +(datetime.date.today() + datetime.timedelta(days=1)).strftime('%Y-%m-%d') + '/headlines.csv')
    return links

# %%
data = runDaily()
data
# Out:
#                  Date                                           Headline  \
# 0   Oct-26-21 02:21PM  Facebooks Planning a Major Spending Spree. Nvi...
# 1             02:03PM  UPDATE 1-Cisco creates Apple-specific developm...
# 2             01:58PM  Facebook is spending more, and these companies...
# 3             01:17PM  Cisco creates Apple-specific development team ...
# 4             01:10PM  Cisco creates Apple-specific development team ...
# 5   Oct-26-21 12:05PM  Should I Buy Fastenal Company (FAST)? Insider ...
# 6   Oct-24-21 09:53AM  Investing in Fastenal (NASDAQ:FAST) five years...
# 7   Oct-19-21 05:21AM              3 Stocks Insiders Are Buying Benzinga
# 8   Oct-18-21 10:43AM  This Is an Earnings Call That Smart Investors ...
# 9   Oct-14-21 01:31PM  10 Stocks in the Limelight After Earnings Repo...
# 10  Oct-26-21 04:30PM  Twitter Says Apples Privacy Changes Had Little...
# 11            04:23PM  Facebook Analysts Look Past Outlook Miss to Lo...
# 12            04:19PM  Apple not entirely to blame for advertisers fr...
# 13            04:09PM  Alphabet beats sales estimates, posts record p...
# 14            04:05PM  Facebook Ends Below Key Level for First Time S...
# 15  Oct-26-21 04:55AM  Kansas City Southern Is Powering Its Way Highe...
# 16  Oct-25-21 04:30PM  New Strategically-Located Central Bajío Vehicl...
# 17  Oct-22-21 01:27PM  Landstar's (LSTR) Q3 Earnings & Revenues Beat,...
# 18            12:11PM  GATX Q3 Earnings Surpass Estimates, Revenues I...
# 19            06:35AM  10 Stocks to Buy According to Bluegrass Capita...
# 20  Oct-25-21 10:47AM  What Awaits Automatic Data Processing (ADP) in...
